# %% [markdown]
# **If you lost points on the last checkpoint you can get them back by responding to TA/IA feedback**
#
# Update/change the relevant sections where you lost those points, make sure you respond on GitHub Issues to your TA/IA to call their attention to the changes you made here.
#
# Please update your Timeline... no battle plan survives contact with the enemy, so make sure we understand how your plans have changed.

# %% [markdown]
# # COGS 108 - EDA Checkpoint

# %% [markdown]
# # Names
#
# - Natalie Abel
# - Anthony Manrique
# - Jack Multani
# - Sasha Rashid
# - Abdullah Ahmed

# %% [markdown]
# # Research Question

# %% [markdown]
# What are the multifaceted factors contributing to the home field advantage in the NFL, considering variables such as weather conditions, home attendance, geographical location, and team performance? How do these factors interact, and to what extent do they individually and collectively influence the outcomes of games and the overall success of teams in their home stadiums?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Across the NFL, teams are required to play 50% of games at their home stadium while the other 50% is played at away stadiums. However, when playing at their home stadium, teams are favored to have a ‘home-field advantage’ that offers them a better chance of winning than the opposing team. But what exactly makes playing on their home turf such a big deal? In our project, we aim to research what creates a home-field advantage by looking at different factors like the weather, the number of fans in attendance, the game performance of the team, and even where the team is based. By digging into these details, we hope to understand why playing at home seems to give NFL teams an edge, what specific factors, if any, may contribute more to the advantage, and how these factors collectively affect the team’s success on their home field.
#
# We looked at how weather conditions in general affect all NFL games, whether they are home or away. A study conducted by a group of students at Stanford University attempted to find whether the results of NFL games could be affected by temperature or precipitation that was occurring during the game [<a name="cite_ref-1"></a>[1](#cite_note-1)]. The study made distinctions between types of weather conditions and examined the offensive and defensive efficiency of the teams playing in the game. A linear regression of weather factors was then performed on the score measures of the game including “Points Per Game (PPG), Score Differential between Home Team and Away Team, Home Score, and Away Score”. The study concluded that poor weather that occurs at home games is a greater advantage for the home team as the home players are more used to playing in the city’s environment. In addition, for weather that involved rain or high wind speeds, the average score for the away team resulted in a negative value, indicating an advantage for the home team. As this study is similar to our research project, we hope to take a further step and look at the individual scores of players to examine player performance in specific weather conditions.
#
# Another study conducted on a team’s winning percentage at home focused on whether fans or spectators positively impacted the home team’s chances of winning [<a name="cite_ref-2"></a>[2](#cite_note-2)]. The study narrowed their research on the 2020 NFL season during the COVID-19 pandemic as there were no to little fans allowed on stadiums during this time. By comparing home attendance in the 2020 NFL season to previous seasons, the study also looked at betting odds of the home team to determine whether there was an increase in odds during the 2020 NFL season compared to other years. After investigating the mean and median values of closing betting lines, the study found that the 2020 NFL season occurred in lower closing betting odds due to the absence of a home attendance, thus shifting the bettings favors to be more balanced towards the away team. In addition, the study found that in non-2020 seasons, the home team was favored by 2.50 points, indicating that 16% of an incorporated home advantage within a betting odd is determined by home attendance. In comparison to the home team, away teams during the non-2020 seasons were only favored by 0.16 points but increased to 0.85 points during the 2020 NFL season, indicating that away teams are more likely to win an away game without the presence of a home crowd. As this study seems to base their results only on bettings odds from the 2007 - 2020 NFL seasons, we would like to shift away from the methodology used within this study and instead incorporate one that focuses on the change in home attendance per each game and the statistics of players while they play in both home and away games.
#
# In addition to our own research on datasets that pertain to home-field advantage in the NFL, a previous project was found that investigated this phenomenon. In his project [<a name="cite_ref-3"></a>[3](#cite_note-3)], he observed the datasets related to fan base, stadium type (indoor or outdoor), the effects of having to travel, and the time zone in which the games were played. From wrangling through his data, sorting missing values, and finding the p-values in his statistical analysis, he came to the conclusion that there was no real “home-field advantage” for teams in the NFL. He believes that this is due to the NFL designating large amounts of money to minimize this concept and make the playing field more level, where the players are ready and comfortable playing either at home or away. This analysis was helpful in giving us an idea of what to look for in our datasets, and it puts into perspective that there could be a null hypothesis from our research. However, we are determined to incorporate other variables in the equation, with datasets on weather conditions and location of the game to determine if those fit the home-field advantage paradigm. We still want to observe the fan base and determine our own observations from more recent data, since his study was conducted from the 2017 NFL season.
#
# References:
# 1. <a name="cite_note-1"></a> [^](#cite_ref-1) https://web.stanford.edu/class/stats50/projects16/Houghton-BerryParkPierce-paper.pdf
# 2. <a name="cite_note-2"></a> [^](#cite_ref-2)https://digitalscholarship.unlv.edu/grrj/vol26/iss1/6/
# 3. <a name="cite_note-3"></a> [^](#cite_ref-3)https://medium.com/@m.grohnke/home-field-advantage-in-the-nfl-7b3bd1503109

# %% [markdown]
# # Hypothesis

# %% [markdown]
# The impact of abnormal weather conditions during NFL home games has a more significant effect on win rates than the presence or absence of fan attendance.
#
# We hypothesize that weather conditions and fan attendance collectively influence home game win rates despite certain factors having more of an impact. Previous research revealing a lack of significant correlation between fan base and home-field advantage, coupled with the unique challenges posed by unpredictable weather conditions, supports our belief.

# %% [markdown]
# # Data

# %% [markdown]
# # Dataset #1 - Weather data
# Link to the dataset: https://www.kaggle.com/datasets/tombliss/weather-data
#
# Includes relevant information on location of the game, the stadium type, temperature, humidity, windspeed, etc., all of which are factors that are being observed in regards to game success/win rate
#
# | File Name               | Number of Observations | Number of Variables | Content Description                                                                          |
# |-------------------------|------------------------|----------------------|----------------------------------------------------------------------------------------------|
# | games.csv               | 5593                   | 6                    | Game ID, season, stadium name, start and end time of the game, and timezone played          |
# | games_weather.csv       | 37155                  | 12                   | Game ID, weather data source, distance from station, date and time of measurement, temperature, humidity, precipitation, dewpoint, windspeed, pressure, and wind direction at game time |
# | stadium_coordinates.csv | 59                     | 6                    | Stadium name, roof type, longitude and latitude of stadium coordinates, azimuth angle of the field |
#
# ## Important Variables
#
# | Variable       | Data Type | From File                    | Description                                                     |
# |----------------|-----------|------------------------------|-----------------------------------------------------------------|
# | Roof Type      | Object    | stadium_coordinates.csv      | Whether the stadium has an indoor, outdoor, or retractable roof |
# | game_id        | Integer   | games.csv                    | ID corresponding to the game                                    |
# | Season         | Object    | games.csv                    | Season the game takes place in                                   |
# | StadiumName    | Object    | games.csv                    | Name of the stadium                                             |
# | game_id        | Integer   | games_weather.csv            | ID corresponding to the game                                    |
# | Temperature    | Float     | games_weather.csv            | Temperature in Fahrenheit                                       |
# | Humidity       | Float     | games_weather.csv            | Humidity in percentage                                          |
# | DewPoint       | Float     | games_weather.csv            | Dew point in Fahrenheit                                         |
# | Precipitation  | Float     | games_weather.csv            | Precipitation in inches                                         |
# | WindSpeed      | Float     | games_weather.csv            | Speed of wind in mph                                            |
# | WindDirection  | Float     | games_weather.csv            | Angle of direction of wind                                      |
# | Pressure       | Float     | games_weather.csv            | Pressure in inches of mercury                                   |
#
# ## Proxies
# The important variables mentioned above within games.csv, games_weather.csv, and stadium_coordinates.csv can help us answer questions related to how weather affects the NFL games. We can use precipitation patterns, wind speed and temperature because these variables might play factors in throwing the football, players adjustment to any outlier temperatures, and overall game conditions. The variables in games.csv will allow us to match each game between the three csv files.
#
# ## Cleaning the Data
# We will need to clean the unnecessary columns in the weather file, including the longitude, latitude, and stadiumazimuthangle in stadium_coordinates.csv.  Additional columns like timestartgame, timeendgame, and TZOffset in games.csv are not useful for our data, and will be filtered out. In games_weather.csv, we will clean out the data for source, distancetostation, and timemeasure as we are only focused on the weather aspects that can affect the game (rain, heat, snow, and wind).
#
#
# We streamlined our data by eliminating unnecessary variables and combining the contents of the three separate csv files from Dataset #1 into a single dataset to make it easy to follow weather content and games.

# %%
import numpy as np
import pandas as pd

#Load datasets
weather_data = pd.read_csv('games_weather.csv')
coordinates = pd.read_csv('stadium_coordinates.csv')
games_2 = pd.read_csv('games_2.csv')


#Drop columns containing unneeded variables 
games_2 = games_2.drop(columns = ['TimeStartGame', 'TimeEndGame', 'TZOffset'])
weather_data = weather_data.drop(columns = ['Source', 'DistanceToStation', 'TimeMeasure', 'EstimatedCondition'])
coordinates = coordinates.drop(columns = ['Longitude', 'Latitude', 'StadiumAzimuthAngle'])


#Group weather data by game and get mean in order to consolidate dataset
weather_data = weather_data.groupby('game_id').mean()
weather_data.head()


#Create new weather_games dataset by merging weather_data and games_2
weather_games = pd.merge(weather_data, games_2, on = 'game_id')


#Only keep data from 2019 and before 
weather_games = weather_games[weather_games['Season'] <= 2019]
weather_games.head()


#Create new weather dataset by merging weather_games and coordinates
weather = pd.merge(weather_games, coordinates, on = 'StadiumName')


#Remove all data from sports other than the NFL 
weather = weather.loc[~((weather['HomeTeam'] == 'Wembley') | (weather['HomeTeam'] == 'Twickenham') | (weather['HomeTeam'] == 'Tottenham') | (weather['HomeTeam'] == 'Toronto') | (weather['HomeTeam'] == 'Mexico City'))]
weather.head()
# Out:
#       game_id  Temperature   DewPoint   Humidity  Precipitation  WindSpeed  \
# 0  2000090300    78.697143  74.042857  86.428571       0.128714   3.782857
# 1  2000090300    78.697143  74.042857  86.428571       0.128714   3.782857
# 2  2000090301    79.820000  71.510000  76.500000       0.000000   7.516667
# 3  2000090302    80.137143  74.660000  83.571429       0.000000   7.262857
# 4  2000090303    67.588571  61.031429  80.000000       0.000000   8.928571
#
#    WindDirection   Pressure  Season           StadiumName HomeTeam RoofType
# 0     231.666667  29.860300    2000        Giants Stadium      NYG  Outdoor
# 1     231.666667  29.860300    2000        Giants Stadium      NYJ  Outdoor
# 2     230.000000  29.922267    2000  Three Rivers Stadium      PIT  Outdoor
# 3     170.000000  29.878443    2000            FedExField      WAS  Outdoor
# 4      60.000000  29.995300    2000     U.S. Bank Stadium      MIN   Indoor

# %% [markdown]
# # Dataset #2 - NFL stadium attendance data
# Link to the dataset: https://www.kaggle.com/datasets/sujaykapadnis/nfl-stadium-attendance-dataset
#
# Includes relevant information on home vs. away attendance of teams and win rate/game performance in relation to those statistics
#
# | Name of File    | Number of Observations | Number of Variables | What the File Contains                                                                                                |
# |------------------|------------------------|----------------------|------------------------------------------------------------------------------------------------------------------------|
# | attendance.csv   | 10846                  | 8                    | Team city, team name, season year, total attendance across 17 weeks, home attendance, away attendance, week number, weekly attendance number |
# | games.csv        | 5324                   | 19                   | Season year, week number, home team, away team, winning team, tie or not, day of week, date (excluding year), time of game start, points by winning team, points by losing team, yards by winning team, yards by losing team, turnovers by losing team, turnovers by winning team, home team name, home team city, away team name, away team city |
# | standings.csv    | 638                    | 15                   | Team city, team name, season year, wins, losses, offensive performance, defensive performance, point differential, margin of victory, average quality of opponent, team quality relative to average, team offense quality, team defense quality, made playoffs or not, won Super Bowl or not |
#
#
# ## Important Variables
#
# | Variable           | Data Type | From File          | Description                                     |
# |--------------------|-----------|--------------------|-------------------------------------------------|
# | weekly_attendance  | Integer   | attendance.csv     | Weekly attendance number (home and away combined)|
# | team_name          | String    | attendance.csv     | Team name                                       |
# | team               | String    | attendance.csv     | Team’s city                                     |
# | total              | Integer   | attendance.csv     | Total attendance across all 17 weeks             |
# | home               | Integer   | attendance.csv     | Home attendance across all 17 weeks              |
# | away               | Integer   | attendance.csv     | Away attendance across all 17 weeks              |
# | week               | Integer   | attendance.csv     | Week number                                     |
# | team               | String    | standings.csv      | Team’s city                                     |
# | team_name          | String    | standings.csv      | Team name                                       |
# | wins               | Integer   | standings.csv      | Wins across all 17 weeks                        |
# | loss               | Integer   | standings.csv      | Losses across all 17 weeks                      |
# | margin_of_victory  | Float     | standings.csv      | (Points scored - points allowed) / games played |
# | year               | Integer   | games.csv          | Season year                                    |
# | week               | Integer   | games.csv          | Week number                                    |
# | home_team          | String    | games.csv          | Home team                                      |
# | away_team          | String    | games.csv          | Away team                                      |
# | winner             | String    | games.csv          | Winning team                                   |
# | pnts_win           | Integer   | games.csv          | Points by winning team                         |
#
# ## Proxies
# The variables mentioned above will be able to assist us in most of our analysis. Weekly attendance can contribute to how well a team is doing, as well as specific game attendance for those teams – have to access the same teams, year, and week of games from both datasets. Home vs away fan rate compared to total in relation to wins could be a determining factor. Other factors from the game (yds_win, turnovers_win, etc.) could indicate team performance more than wins (maybe an unlucky game if there is no win but high yds_win, turnovers_win, etc.).
#
# ## Cleaning the Data
# We changed the NaN values in the “tie” column to be “No” if NaN to be easier to read. We removed variables in the original CSVs (strength_of_schedule, simple_rating, offensive_ranking, defensive_ranking, playoffs, sb_winner) as this data wasn’t relative to the analysis on attendance for home teams and rate of winning.
#
#
# We then merged the “standings.csv” and “attendance.csv” to make a “standings_attendance” csv file for Dataset #2 in order to combine the aspects of attendance for each game and the game statistics of winning, yards won/loss, margin of victory, etc.

# %%
# Load datasets 
games = pd.read_csv('games.csv')
attendance = pd.read_csv('attendance.csv')
standings = pd.read_csv('standings.csv')


# Drop columns containing variables that aren’t needed in standings.csv and games.csv
standings = standings.drop(columns = ['strength_of_schedule', 'simple_rating', 'offensive_ranking', 'defensive_ranking', 'playoffs', 'sb_winner'])
games = games.drop(columns = ['time', 'day', 'away_team'])


#Remove rows containing data from non-regular season games 
games = games.loc[~((games['week'] == 'WildCard') | (games['week'] == 'Division') | (games['week'] == 'ConfChamp') | (games['week'] == 'SuperBowl'))]


#Replace all “Nan” values with “No” 
games['tie'] = games['tie'].fillna('No')
games.head()
# Out:
#    year week            home_team               winner tie         date  \
# 0  2000    1    Minnesota Vikings    Minnesota Vikings  No  September 3
# 1  2000    1   Kansas City Chiefs   Indianapolis Colts  No  September 3
# 2  2000    1  Washington Redskins  Washington Redskins  No  September 3
# 3  2000    1      Atlanta Falcons      Atlanta Falcons  No  September 3
# 4  2000    1  Pittsburgh Steelers     Baltimore Ravens  No  September 3
#
#    pts_win  pts_loss  yds_win  turnovers_win  yds_loss  turnovers_loss  \
# 0       30        27      374              1       425               1
# 1       27        14      386              2       280               1
# 2       20        17      396              0       236               1
# 3       36        28      359              1       339               1
# 4       16         0      336              0       223               1
#
#   home_team_name home_team_city away_team_name away_team_city
# ...

# %%
# Create new weekly_attendance dataset from attendance.csv by dropping columns containing data from the whole season 
weekly_attendance = attendance.drop(columns = ['total', 'home', 'away'])


# Only keep non- “Nan” values
weekly_attendance = weekly_attendance[weekly_attendance['weekly_attendance'].notna()]


#Convert float values to integer
weekly_attendance['weekly_attendance'] = weekly_attendance['weekly_attendance'].astype(int)
weekly_attendance.head()


# Create new total_attendance dataset from attendance.csv by dropping weekly attendance columns 
total_attendance = attendance.drop(columns = ['weekly_attendance', 'week']).drop_duplicates().reset_index().drop(columns = ['index'])
total_attendance.head()
# Out:
#         team  team_name  year    total    home    away
# 0    Arizona  Cardinals  2000   893926  387475  506451
# 1    Atlanta    Falcons  2000   964579  422814  541765
# 2  Baltimore     Ravens  2000  1062373  551695  510678
# 3    Buffalo      Bills  2000  1098587  560695  537892
# 4   Carolina   Panthers  2000  1095192  583489  511703

# %%
#Drop columns from total_attendance to avoid duplicate columns when merging datasets
total_attendance = total_attendance.drop(columns = ['team_name', 'year'])


#Create new standings_attendance dataset by merging total_attendance and standings
standings_attendance = pd.merge(standings, total_attendance, on = 'team')
standings_attendance.head()
# Out:
#     team team_name  year  wins  loss  points_for  points_against  \
# 0  Miami  Dolphins  2000    11     5         323             226
# 1  Miami  Dolphins  2000    11     5         323             226
# 2  Miami  Dolphins  2000    11     5         323             226
# 3  Miami  Dolphins  2000    11     5         323             226
# 4  Miami  Dolphins  2000    11     5         323             226
#
#    points_differential  margin_of_victory    total    home    away
# 0                   97                6.1  1118883  589909  528974
# 1                   97                6.1  1119236  587756  531480
# 2                   97                6.1  1144504  585523  558981
# 3                   97                6.1  1158236  587787  570449
# 4                   97                6.1  1143869  580808  563061

# %% [markdown]
# # Results
#
# ## Exploratory Data Analysis

# %% [markdown]
# ### Investigating Home Wins
# We're looking to explore how often are teams winning (at home) and what do their points and yard coverage look like? Mainly, what do the top 10 teams look like?

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# generate a table of games where home_team was also the winner
home_wins_df = games[games['winner'] == games['home_team']]
home_wins_df.head()

# which home teams are winning the most
win_counts = home_wins_df['home_team'].value_counts()

# generate a chart to examine who's winning
sns.color_palette()
sns.barplot(x=win_counts.index, y=win_counts.values)
plt.xticks(rotation=90)

plt.title('Teams with Most Wins')
plt.xlabel('Team')
plt.ylabel('Number of Wins')

plt.show()

# note: some teams moved cities! san diego chargers -> los angeles chargers

# %% [markdown]
# **Distribution of Variables:**
# The distribution is relatively normal across teams, where most teams have most wins being about 80-100.
#
# **Outliers:**
# Yes, there are a couple of outliers. The Rams and Chargers have the least amount of wins at about 20 each, while the rest of the teams range from 60-120.
#
# **Relationship Between Variables:**
# As most teams show a consistent win rate, with only a couple of teams showing outliers and one team (Patriots) having the most wins, the team itself is not a determining factor of win rates but outside factors relating to the teams.
#
# **What Was Learned:**
# Most teams have a win rate around 80 wins in the season, showing a consistent pattern in performance, which could indicate that there is no home advantage from factors like weather and home attendance. Also unaccounted for was that teams may have switched locations such as the San Diego Chargers moving to Los Angeles.

# %%
# who are the top 10?
top_10_home_winning_teams = home_wins_df['home_team'].value_counts()[:10].index.tolist()
top_10_home_winning_teams 

# looking only at the top 10 could definitely lead into bias! but we're exploring the data for now
top_10_df = home_wins_df[home_wins_df['home_team'].isin(top_10_home_winning_teams)]
top_10_df

top_10_win_counts = top_10_df['winner'].value_counts()
# top_10_win_counts

# %%
# generate a chart to examine who's winning (out of the top 10)
sns.set(style="whitegrid")
sns.color_palette()
sns.barplot(x=top_10_win_counts.index, y=top_10_win_counts.values)
plt.xticks(rotation=90)

plt.title('Top 10 Teams with Most Wins')
plt.xlabel('Team')
plt.ylabel('Number of Wins')

plt.show()

# %% [markdown]
# **Distribution of Variables:**
# The distribution is, again, relatively even among teams, where the top 10 teams who have the most wins range from 100-120 wins.
#
# **Outliers:**
# No, there are no outliers in this dataset as it is the top 10 teams, so their number of wins are relatively close to one another.
#
# **Relationship Between Variables:**
# The Patriots show the most wins among the top 10, with Chiefs on the lower tale at about 90 wins. The variability between the number of wins in a season is slim between these teams.
#
# **What Was Learned:**
# The top 10 teams are relatively close to one another in performance, and a lot of these teams are from the East Coast/Midwest – this could point to weather factors affecting their games and the amount of wins they have.

# %%
# how much are the top 10 teams typically scoring when they win?
sns.color_palette()
sns.boxplot(x='home_team', y='pts_win', data=top_10_df, order=top_10_home_winning_teams, showmeans=True)
plt.xticks(rotation=90)

plt.title('Average Points In Won Home Games')
plt.xlabel('Top 10 Teams (Ordered by Most Wins)')
plt.ylabel('Average Points')

plt.show()

# %% [markdown]
# **Distribution of Variables:**
# The distribution is relatively normal across the top 10 teams, where the points they win in a game have a median of about 25-30, and range from 10 to 50 in the 25th and 75th percentiles. There are a few outliers among some teams, which de-normalizes the data.
#
# **Outliers:**
# Yes, there are some outliers among teams, such as outliers among the Eagles, Chiefs, Seahawks, Colts, Packers, Ravens, and Patriots. These outliers remain above the 75th percentile of the data.
#
# **Relationship Between Variables:**
# Most teams maintain a points won rate of about 30 when playing at home, demonstrating similar performance when having a home game. Some teams have points ranging from 50-60, which could indicate weather factors or other home advantages.
#
# **What Was Learned:**
# The data is consistent among points won in a game, and as previously stated, the top 10 teams are from regions with severe weather in the East Coast or Midwest, and this could impact the amount of points they allocate a game.

# %%
# how much are the top 10 teams yard coverage typically have when they win?
sns.boxplot(x='home_team', y='yds_win', data=top_10_df, order=top_10_home_winning_teams, showmeans=True)
plt.xticks(rotation=90)

plt.title('Average Yards In Won Home Games')
plt.xlabel('Top 10 Teams (Ordered by Most Wins)')
plt.ylabel('Average Yards')

plt.show()

# %% [markdown]
# **Distribution of Variables:**
# The distribution is relatively normal, with most top 10 teams hitting a median of about 400 yards in a game. The Patriots, who have the most wins, don’t have the most yardage, so this could indicate that yardage and win rate are not highly correlated.
#
# **Outliers:**
# There are a few outliers among teams, one being prevalent as it is the only one below the 25th percentile (Seahawks game of below 200 yards).
#
# **Relationship Between Variables:**
# For the most part, the top teams with the most wins across seasons have the same yardage earned in games.
#
# **What Was Learned:**
# Some teams show a higher winning rate with lower yardage compared to other teams, so there may not be a strong correlation between yards gained and winning the game.

# %% [markdown]
# ### Game Attendance

# %%
#assert size of the figures
fig, ax = plt.subplots(figsize=(20, 10))
#create histogram showing frequency distribution of weekly attendance for teams
sns.histplot(weekly_attendance['weekly_attendance'], color='blue')
# Out:
# <Axes: xlabel='weekly_attendance', ylabel='Count'>

# %% [markdown]
# **Distribution of Variables:**
# Normal distribution, no left or right skew.
#
# **Outliers:**
# Outlier of about 25,000.
#
# **Relationship Between Variables:**
# As the frequency of fan attendance provides a normal distribution of the data where it hits a peak of about 70,000 fans being the most frequent for weekly attendance. The frequency distribution is gradually increasing from 20,000 to 70,000 fans, with dips here and there but an overall upward trend; then, after this peak, the data begins to decrease in frequency, as fans increase to 100,000 and frequency becomes less.
#
# **What Was Learned:**
# The most frequent number of fans weekly for teams was about 70,000, and with a normal distribution with one outlier, it seems that most teams follow the same home weekly attendance trend of having higher distributions between 60,000 and 80,000 people.

# %%
#assert size of figure
plt.figure(figsize=(10, 6))
#create scatter plot between wins and home attendance
plt.scatter(standings_attendance['wins'], standings_attendance['home'])
plt.xlabel('Wins')
plt.ylabel('Home Attendance')
plt.title('Correlation between Wins and Home Attendance')
# Out:
# Text(0.5, 1.0, 'Correlation between Wins and Home Attendance')

# %% [markdown]
# **Distribution of Variables:**
# Normal distribution, with both extremes of little wins vs. a lot of wins not having many data points.
#
# **Outliers:**
# No outliers.
#
# **Relationship Between Variables:**
# Most teams have home attendance ranging from 40,000-60,000, and this doesn’t change as wins increase (distribution stays constant).
#
# **What Was Learned:**
# Home attendance doesn’t affect win rates, as the most data points come from a home attendance in the range of 40,000-60,000, and this stays constant, even with only 2 wins vs. 14 wins. Thus, as wins show an increase for some teams, there is no relationship showing that home attendance increases and establishes a relationship between the two variables.

# %%
#assert size of figure
fig, ax = plt.subplots(figsize=(20, 10))
#create boxplot showing home attendance distribution across teams
sns.boxplot(total_attendance['home'], color='orange')
# Out:
# <Axes: ylabel='home'>

# %% [markdown]
# **Distribution of Variables:**
# There is an uneven distribution of home fans among teams with several outliers.
#
# **Outliers:**
# Yes, outliers outside of the 25th and 75th percentiles, from 20,000 to 40,000 home fans, and about 68,000 to 80,000 home fans.
#
# **Relationship Between Variables:**
# As there are many outliers, there doesn’t seem to be a clear relationship between home attendance and the frequency of that number. There seems to be a lot of variability in how many home fans attend the games.
#
# **What Was Learned:**
# The median number of home fans for games between teams is about 55,000, with the 25th percentile being 40,000 and the 75th percentile being about 70,000. There are several outliers among the dataset, meaning home attendance is variable for teams and isn’t a constant factor.

# %%
#assert size of figure
fig, ax = plt.subplots(figsize=(20, 10))
#plot boxplot showing away attendance across teams
sns.boxplot(total_attendance['away'], color='orange')
# Out:
# <Axes: ylabel='away'>

# %% [markdown]
# **Distribution of Variables:**
# The distribution is a little more normal with fewer outliers but still has outliers in the lower range of the numbers of away fans.
#
# **Outliers:**
# Yes, in the data outside of the 25th percentile, there are about 7 outliers.
#
# **Relationship Between Variables:**
# There seems to be a distribution of the data ranging from 40,000 to 60,000 away fans, with a median of 54,000. The data is pretty evenly distributed and constant.
#
# **What Was Learned:**
# There is a more consistent amount of away fans for games, whether that be due to factors of travel, away-fan allocated seating, etc. The home attendance was much more variable across teams, but despite a few outliers, away attendance doesn’t exceed 60,000 for teams.

# %% [markdown]
# ## Average Weather and Temperature Conditions

# %%
#Create a new dataframe ‘averageConditions’ which contains the average Temperature, Humidity, Precipitation, and WindSpeed of each NFL team’s games from 2000 - 2019.
averageConditions = weather.groupby(['HomeTeam']).agg({
    'Temperature': 'mean',
    'Humidity': 'mean',
    'Precipitation': 'mean',
    'WindSpeed': 'mean'
}).reset_index()
#Create a team_name_mapping to change the team name abbreviation to the full team name
team_name_mapping = {
    'ARI': 'Arizona Cardinals',
    'ATL': 'Atlanta Falcons',
    'BAL': 'Baltimore Ravens',
    'BUF': 'Buffalo Bills',
    'CAR': 'Carolina Panthers',
    'CHI': 'Chicago Bears',
    'CIN': 'Cincinnati Bengals',
    'CLE': 'Cleveland Browns',
    'DAL': 'Dallas Cowboys',
    'DEN': 'Denver Broncos',
    'DET': 'Detroit Lions',
    'GB': 'Green Bay Packers',
    'HOU': 'Houston Texans',
    'IND': 'Indianapolis Colts',
    'JAX': 'Jacksonville Jaguars',
    'KC': 'Kansas City Chiefs',
    'LAC': 'Los Angeles Chargers',
    'LAR': 'Los Angeles Rams',
    'LV': 'Las Vegas Raiders',
    'MIA': 'Miami Dolphins',
    'MIN': 'Minnesota Vikings',
    'NE': 'New England Patriots',
    'NO': 'New Orleans Saints',
    'NYG': 'New York Giants',
    'NYJ': 'New York Jets',
    'OAK': 'Oakland Raiders',
    'PHI': 'Philadelphia Eagles',
    'PIT': 'Pittsburgh Steelers',
    'SF': 'San Francisco 49ers',
    'SD': 'San Diego Chargers',
    'SEA': 'Seattle Seahawks',
    'STL': 'Saint Louis Rams',
    'TB': 'Tampa Bay Buccaneers',
    'TEN': 'Tennessee Titans',
    'WAS': 'Washington Commanders'
}
#Apply mapping
averageConditions['HomeTeam'] = averageConditions['HomeTeam'].map(team_name_mapping)
averageConditions
# Out:
#                  HomeTeam  Temperature   Humidity  Precipitation  WindSpeed
# 0       Arizona Cardinals    76.425330  27.465772       0.000159   5.756100
# 1         Atlanta Falcons    62.783753  60.117362       0.005250   6.500104
# 2        Baltimore Ravens    57.017373  53.913174       0.003614   7.342822
# 3           Buffalo Bills    50.557395  66.051976       0.005112  11.595984
# 4       Carolina Panthers    61.995095  54.991165       0.003000   5.068311
# 5           Chicago Bears    49.612973  63.330634       0.003578  10.100495
# 6      Cincinnati Bengals    55.182664  62.192667       0.004317   7.687511
# 7        Cleveland Browns    51.805876  63.127583       0.003230  11.916402
# 8          Dallas Cowboys    66.238649  53.758950       0.003075   9.032978
# 9          Denver Broncos    50.211833  43.006781       0.001062   8.551060
# 10          Detroit Lions    47.137418  61.836439       0.003173   9.672193
# ...

# %%
weather2 = weather
#Apply mapping of team name abbreviation to full team name
weather2['HomeTeam'] = weather2['HomeTeam'].map(team_name_mapping)
plt.figure(figsize=(16, 8))
#Graph the temperature values and average temperature of NFL teams from games in the 2000 - 2019 seasons
sns.boxplot(x='HomeTeam', y='Temperature', data=weather2, showmeans=True)
plt.title('Temperature Conditions of Home Teams From 2000 - 2019')
plt.yticks(range(0, 100, 10))
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Distribution of Variables:**
# The NFL teams in the above boxplot include distributions that are both positively and negatively skewed. This is because there exist boxplots in which the median > mean or the median < mean where the median is labeled as the horizontal line marker, and the mean is an upward green arrow for each team’s data.
#
# **Outliers:**
# Five teams contain outliers: Oakland Raiders, Miami Dolphins, San Francisco 49ers, Tampa Bay Buccaneers, and the Houston Texans.
#
# **Relationship Between Variables:**
# Most teams contain temperatures from 40°F - 65°F, with some teams, like the Miami Dolphins and Tampa Bay Buccaneers, achieving higher temperature ranges from 70°F - 85°F.
#
# **What Was Learned:**
# There isn’t much variation in temperature conditions within the NFL, but there are some teams that achieve much higher temperature ranges than others.

# %%
plt.figure(figsize=(16, 8))
#Graph the humidity values and average temperature of NFL teams from games in the 2000 - 2019 seasons
sns.boxplot(x='HomeTeam', y='Humidity', data=weather2, showmeans=True)
plt.title('Humidity Conditions of Home Teams From 2000 - 2019')
plt.yticks(range(0, 110, 10))
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Distribution of Variables:**
# The NFL teams in the above boxplot include distributions that are both positively and negatively skewed. This is because there exist boxplots in which the median > mean or the median < mean where the median is labeled as the horizontal line marker, and the mean is an upward green arrow for each team’s data.
#
# **Outliers:**
# Six teams contain outliers: Oakland Raiders, Miami Dolphins, San Diego Chargers, Seattle Seahawks, Arizona Cardinals, and Los Angeles Rams.
#
# **Relationship Between Variables:**
# Most teams contain humidity percentages ranging from 40 to 70. In addition, the Arizona Cardinals have a low humidity range from about 18 to 32 when compared to other teams in the NFL.
#
# **What Was Learned:**
# Humidity doesn’t seem to differ across cities in the NFL, indicating that humidity may not play a factor into whether a team plays better in their home games.

# %%
plt.figure(figsize=(16, 8))
#Graph the wind speed values and average wind speed of NFL teams from games in the 2000 - 2019 seasons
sns.boxplot(x='HomeTeam', y='WindSpeed', data=weather2, showmeans=True)
plt.title('Wind Conditions of Home Teams From 2000 - 2019')
plt.yticks(range(0, 45, 5))
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Distribution of Variables:**
# The NFL teams in the above boxplot include distributions that are positively skewed. This is because there exist boxplots in which the median < mean, where the median is labeled as the horizontal line marker, and the mean is an upward green arrow for each team’s data.
#
# **Outliers:**
# In the above boxplot, all but three NFL teams contain outliers: Pittsburgh Steelers, New Orleans Saints, and Los Angeles Rams. This may indicate that an unusual wind speed that is above the boxplot range for a particular team may affect the team’s chances of winning a game in their home stadium as they may not be used to the outlier wind speed.
#
# **Relationship Between Variables:**
# From the above plot, most boxplots are ranging from about 5 to 13 miles per hour, with the Cleveland Browns having a higher range of wind speed from about 7 to 15 miles per hour. As the wind speed range for the Cleveland Browns isn’t that much higher than the rest of the teams, we can assume that most of these teams play in similar conditions in their home games.
#
# **What Was Learned:**
# As almost all of the teams have outliers for wind conditions, and since most of the teams play in similar conditions, we can assume that days with unusually higher wind speed can affect a team’s chances of winning at home. This may be because they are not adjusted to higher wind speed which can affect their play.

# %%
average_temp = weather['Precipitation'].mean()
plt.figure(figsize=(16, 8))
#Graph the precipitation values of NFL teams from games in the 2000 - 2019 seasons
sns.scatterplot(x='HomeTeam', y='Precipitation', data=weather2)
#Graph the average temperature value of NFL teams from games in the 2000 - 2019 seasons
sns.scatterplot(x='HomeTeam', y='Precipitation', data=averageConditions, color='red', s=200, label='Mean Precipitation')
plt.title('Precipitation Conditions of Home Teams From 2000 - 2019')
plt.xticks(rotation=90)
plt.ylim(0, 0.02)
plt.show()

# %% [markdown]
# **Distribution of Variables:**
# There does not seem to be a relationship between the distribution of precipitation for each NFL team, as the precipitation values can vary anywhere from 0.0000 to 0.0200. As a result, when it rains in a team’s home game, there does not seem to be a relationship between how much precipitation will actually occur.
#
# **Outliers:**
# There are outliers in the above scatterplot as there are teams with low mean precipitation values that have multiple precipitation values that are much higher than the mean.
#
# **Relationship Between Variables:**
# Most teams have a mean precipitation value of about 0.0030, with some teams reaching a mean precipitation value of 0.0100. In addition, each team has precipitation values that range from 0.000 to 0.0200.
#
# **What Was Learned:**
# Rainy conditions could impact a team’s performance in their home games, as most teams have relatively low mean precipitation means. As a result, in games with much higher precipitation values, a team may perform better or worse due to the unfamiliar conditions they are playing in.

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# Potential ethical concerns would be missing perspectives on bias in how the stadium is built for that fan base (how many people it can hold), as well as there being bias with what players are on the teams and how that affects the stadium attendance as well. There would be no risk of bias in determining fan base as the dataset for stadium attendance provides data on home attendance and away attendance within the stadium.
# There could be bias in terms of who composes our datasets as they could favor or support a particular team in the NFL, and the data could reflect that. We also need to ensure that we focus on multiple NFL teams, not ones based on specific location (east or west coast) in order to get a fair representation for our data. Lastly, there is bias in what NFL season we are looking at for our data, where certain years hold different data depending on outside factors (covid, inflation rates, etc.) that affect game attendance.
# As far as sorting out these biases, we plan to focus on the last 20 seasons of NFL, where we can see the trend in attendance and weather factors across multiple seasons and determine if there is a clear relationship to success. While some seasons will be due to outside factors like covid, we may determine this data unfeasible and plan to filter it out of the dataset. We also plan to focus on all of the teams within the league, not biasing East or West Coast teams and only getting their statistics. If this is not feasible, we plan to at least focus on one team in every region of the US and their winning percentage relative to the variables we are looking at. As far as the size of the stadium, we will focus more on the rate between home vs. away fans, instead of the total number. This would help address the bias of a bigger stadium being able to hold more fans, and we are more interested in if the home attendance is proportionally greater than the away attendance for games.
# Since the data is mainly on factors involving the home town, from weather to location to fan base, there isn’t a great deal of privacy concerns as we aren’t investigating human subjects. However, there could be privacy concerns with if people are betting on games and how that relates to fan base, as well as team exposure of statistics.
# We will handle these issues by exploring data that has informed consent, as well as focusing more on statistics relative to multiple seasons, rather than any one season. These will follow a clearer pattern for game attendance for home vs. away games as well as weather factors and how that affects winning percentage.

# %% [markdown]
# # Team Expectations

# %% [markdown]
# * Meet weekly through Zoom, possibly twice on weeks where there is a checkpoint due
# * Communicate project updates/issues over text so group members are aware of the project’s progress
# * Contribute equally to overall project and various checkpoint assignments
# * Distribute work evenly and fairly among group members
# * Keep up with commitments made in terms of work to be done outside of meeting times and complete this work in a timely manner
# * If conflicts arise, communicate frustrations respectfully and refer to COGS 108 Team Policies if needed

# %% [markdown]
# # Project Timeline Proposal

# %% [markdown]
# | Date & Time  | Before Meeting | Meeting Agenda  | Assignment Due |
# |---|---|---|---|
# | 02/18/24, 3PM  |  Explore datasets related to project topic | Finalize project topic and research question, finalize meeting times for rest of the project, distribute roles for the project, decide best datasets to use | N/A|
# | 02/25/24, 3PM  |  Choose relevant parts of each dataset and begin cleaning data, begin checkpoint #1 assignment |  Finalize and submit checkpoint #1, discuss what we want to highlight from the data and how we will do the analysis | Checkpoint #1  |
# | 03/03/24, 3PM | Clean up data, begin EDA  | Review clean datasets, and analysis, discuss how we want to visualize the data and what we have learned from the data  | N/A |
# | 03/10/24, 3PM  | Work on analysis, create visualizations, begin drafting “story” that the report will tell, begin checkpoint #2 | Review visualizations, go over how we want the data to be presented/the story we want to tell, finalize and submit checkpoint #2 | Checkpoint #2   |
# | 03/17/24, 3PM   | Work on ethics and privacy, begin working on discussion and conclusion, review & improve completed sections of project  | Finalize discussion, conclusion and results and review full project  | N/A |
# | 03/20/24, 3PM | N/A  | Submit final project and group surveys | Final Project |
